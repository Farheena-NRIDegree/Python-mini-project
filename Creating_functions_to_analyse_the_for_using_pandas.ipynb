# %%
from google.colab import drive

# %%
# mount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read file from the drive
import pandas as pd

# %%
Datasetpath = ('//content/drive/MyDrive/matches_1930_2022.csv')

# %%
df = pd.read_csv(Datasetpath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
import random

# %%
age = []
height = []
Weight = []

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df.shape
# Out:
# (964, 44)

# %%
# loop comprehension
[age.append(random.randint(18,40)) for _ in range (964)]
print(f"Age is now having {len(age)}")
# Out:
# Age is now having 967

# %%
age
# Out:
# [<module 'random' from '/usr/lib/python3.11/random.py'>,
#  <module 'random' from '/usr/lib/python3.11/random.py'>,
#  <module 'random' from '/usr/lib/python3.11/random.py'>,
#  37,
#  20,
#  28,
#  36,
#  22,
#  28,
#  19,
#  32,
#  26,
#  34,
#  22,
#  34,
#  33,
#  19,
#  30,
#  36,
#  36,
#  39,
#  23,
#  28,
#  36,
#  19,
#  21,
#  20,
#  39,
#  19,
#  19,
#  39,
#  24,
#  21,
#  29,
#  29,
#  21,
#  38,
#  37,
#  20,
#  40,
#  40,
#  26,
#  40,
#  33,
#  21,
#  36,
#  40,
#  31,
#  35,
#  39,
#  25,
#  20,
#  19,
#  30,
#  32,
#  36,
#  20,
#  29,
#  31,
#  35,
#  32,
#  19,
#  27,
#  21,
#  19,
#  20,
#  31,
#  35,
#  25,
#  29,
#  20,
#  40,
#  19,
#  28,
#  37,
#  24,
#  34,
#  24,
#  30,
#  35,
#  35,
#  18,
#  29,
#  36,
#  22,
#  39,
#  21,
#  20,
#  24,
#  27,
#  28,
#  35,
#  21,
#  33,
#  29,
#  20,
#  31,
#  19,
#  20,
#  26,
#  21,
#  19,
#  19,
#  19,
#  40,
#  29,
#  25,
#  19,
#  25,
#  40,
#  19,
#  27,
#  40,
#  27,
#  34,
#  22,
#  38,
#  21,
#  18,
#  24,
# ...

# %%
#Adding a new column to the Frame
#Syntax : df['NewColumnName] = List/Series of elements

# %%
# Ensure that the 'age' list has the same length as the DataFrame 'df'
age = age[:df.shape[0]]  # Truncate or pad the list to match the DataFrame length

# Now you can add the new column
df['YearsofExperience'] = age

# %%
age
# Out:
# [<module 'random' from '/usr/lib/python3.11/random.py'>,
#  <module 'random' from '/usr/lib/python3.11/random.py'>,
#  <module 'random' from '/usr/lib/python3.11/random.py'>,
#  37,
#  20,
#  28,
#  36,
#  22,
#  28,
#  19,
#  32,
#  26,
#  34,
#  22,
#  34,
#  33,
#  19,
#  30,
#  36,
#  36,
#  39,
#  23,
#  28,
#  36,
#  19,
#  21,
#  20,
#  39,
#  19,
#  19,
#  39,
#  24,
#  21,
#  29,
#  29,
#  21,
#  38,
#  37,
#  20,
#  40,
#  40,
#  26,
#  40,
#  33,
#  21,
#  36,
#  40,
#  31,
#  35,
#  39,
#  25,
#  20,
#  19,
#  30,
#  32,
#  36,
#  20,
#  29,
#  31,
#  35,
#  32,
#  19,
#  27,
#  21,
#  19,
#  20,
#  31,
#  35,
#  25,
#  29,
#  20,
#  40,
#  19,
#  28,
#  37,
#  24,
#  34,
#  24,
#  30,
#  35,
#  35,
#  18,
#  29,
#  36,
#  22,
#  39,
#  21,
#  20,
#  24,
#  27,
#  28,
#  35,
#  21,
#  33,
#  29,
#  20,
#  31,
#  19,
#  20,
#  26,
#  21,
#  19,
#  19,
#  19,
#  40,
#  29,
#  25,
#  19,
#  25,
#  40,
#  19,
#  27,
#  40,
#  27,
#  34,
#  22,
#  38,
#  21,
#  18,
#  24,
# ...

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
import random  # Make sure to import the random module
import pandas as pd

# ... (Your existing code) ...

# Ensure 'random' refers to the module, not a variable
del random  # Delete the variable if it exists
import random  # Re-import the module

# Now, create the 'YearsofExperience' column
age = []
[age.append(random.randint(18, 40)) for _ in range(df.shape[0])]  # Use the random module here
df['YearsofExperience'] = age

# Calculate 'ASP'
df['ASP'] = df['YearsofExperience'] * df['home_score']

# %%
df.shape
# Out:
# (964, 45)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df['ASP'].plot()
# Out:
# <Axes: >

# %%
df['ASP'].plot(kind = 'bar', color='Red')
# Out:
# <Axes: >

# %%
df.plot(x='YearsofExperience',y='ASP',kind ='hexbin', color='blue')
# Out:
# <Axes: xlabel='YearsofExperience', ylabel='ASP'>

# %%
df.plot(x='YearsofExperience', y='ASP', kind='scatter', color='blue')
# Out:
# <Axes: xlabel='YearsofExperience', ylabel='ASP'>

# %%
df.plot(x='YearsofExperience',y=['ASP','home_score'],kind='bar',color=['Blue','green'])
# Out:
# <Axes: xlabel='YearsofExperience'>

# %%
# Function to get a graph
def getGraph(DataFrame,Column1,Column2):
   from matplotlib import pyplot as plt
   # Check the length of Column1 and Column2
   if len(DataFrame[Column1]) == len(DataFrame[Column2]):
     df.plot(x = Column1, y= Column2, kind='bar' , color=['Black','pink'])
     print('The graph/plot is successfully created ')
   else :
     print('please check the Column size once')

# %%
getGraph(df, 'home_score','away_score')
# Out:
# The graph/plot is successfully created
